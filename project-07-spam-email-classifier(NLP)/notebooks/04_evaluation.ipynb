# %%
# Notebook: 04_Evaluation.ipynb
# ----------------------------

import sys
import os
sys.path.append(os.path.abspath("../src"))  # add src folder to path

from data_loader import load_raw_data
from preprocess import add_clean_column
from evaluate import evaluate_model
from sklearn.model_selection import train_test_split

# ------------------------
# Load and preprocess data
# ------------------------
df = load_raw_data("../data/raw/spam.tsv")
df = add_clean_column(df)

X = df['clean_text']
y = df['label']

# ------------------------
# Split data
# ------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# ------------------------
# Evaluate model
# ------------------------
model_path = "../models/spam_pipeline.joblib"
report = evaluate_model(model_path, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       966
#            1       0.92      0.91      0.91       149
#
#     accuracy                           0.98      1115
#    macro avg       0.95      0.95      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
